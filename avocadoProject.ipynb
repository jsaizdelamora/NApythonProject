# %%
import pandas as pd
avocados = pd.read_csv("avocado.csv")
avocados
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
import pandas as pd
avocados = pd.read_csv("avocado.csv")
sortedAvocados = avocados.sort_values(by="AveragePrice")

# %%
import pandas as pd
avocados = pd.read_csv("avocado.csv")
sortedAvocados = avocados.sort_values(by="AveragePrice")
print("lowest Avocado Price locations and dates:")
print(sortedAvocados.head(3))
print("Highest Avocado Price locations and dates:")
print(sortedAvocados.tail(3))
# Out:
# lowest Avocado Price locations and dates:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 15261          43  2017-03-05          0.44      64057.04      223.84
# 7412           47  2017-02-05          0.46    2200550.27  1200632.86
# 15473          43  2017-03-05          0.48      50890.73      717.57
#
#             4225      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 15261    4748.88      0.00    59084.32      638.68    58445.64         0.00
# 7412   531226.65  18324.93   450365.83   113752.17   330583.10      6030.56
# 15473    4138.84      0.00    46034.32     1385.06    44649.26         0.00
#
#                type  year            region
# 15261       organic  2017  CincinnatiDayton
# 7412   conventional  2017     PhoenixTucson
# 15473       organic  2017           Detroit
# Highest Avocado Price locations and dates:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# ...

# %%
#average price difference between conventional and organic avocados
import pandas as pd
avocados = pd.read_csv("avocado.csv")

avocados.groupby("type") ["AveragePrice"].mean()
# Out:
# type
# conventional    1.158040
# organic         1.653999
# Name: AveragePrice, dtype: float64

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


avocados = pd.read_csv("avocado.csv")
sortedAvocados = avocados.sort_values(by="Date")
sortedAvocados.plot(x="year", y = "AveragePrice", kind="bar" )
plt.show()

# %%
#Determining when the best time to buy avocados to sell at markup was, based on lowest price of Avocados

import pandas as pd
avocados = pd.read_csv("avocado.csv")

#sort listings by lowest price
sortedAvocados = avocados.sort_values(by="AveragePrice")
#find the cheapestListing
cheapestAvocado = sortedAvocados.head(1)
#pull relative date and year of listing
relativeDate = cheapestAvocado["Date"]
relativeYear = cheapestAvocado.iloc[0]['year']

#find comparative high price of avocado for same year
comparatorAvocado = avocados.loc[avocados["year"]==relativeYear ]
comparatorAvocado.sort_values(by="AveragePrice", ascending = False)

print("Highest price differential for avocados in "+ str(relativeYear))
print("Lowest Avocado price was "+ str(cheapestAvocado.iloc[0]["AveragePrice"])+" in "+str(cheapestAvocado.iloc[0]["region"]) )
print("Highest Avocado price was "+str(comparatorAvocado.iloc[0]["AveragePrice"])+" in "+str(comparatorAvocado.iloc[0]["region"] ))
# Out:
# Highest price differential for avocados in 2017
# Lowest Avocado price was 0.44 in CincinnatiDayton
# Highest Avocado price was 1.47 in Albany
